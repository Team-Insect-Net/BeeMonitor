# %%
from bee_monitor import BeeMonitor
# Complete end-to-end analysis!
monitor = BeeMonitor.from_config("default_config.yaml")
results = monitor.analyze_video("/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/test_bee.mp4")

results.to_csv("results.csv")              # ✅ WORKS!
results.save_video("annotated.mp4")         # ✅ WORKS!
stats = results.get_statistics()

# %%
# Out:
# {'total_events': 3,
#  'total_entries': 2,
#  'total_exits': 1,
#  'active_nests': 2,
#  'total_nests': 60,
#  'total_tracks': 3,
#  'nest_activity': {'Entry': {'16': 1, '20': 1}, 'Exit': {'16': 0, '20': 1}}}
