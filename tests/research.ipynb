# %%
from beemonitor import BeeMonitor

# %%
# # Complete end-to-end analysis!
# filename = "/Users/edwardamoah/Documents/GitHub/BeeVision_1/monitoring_data/14s_video.mp4"
# #filename = "/Users/edwardamoah/Documents/GitHub/BeeMonitor/videos/test_bee.mp4"
# #filename = "/Users/edwardamoah/Documents/GitHub/BeeVision_1/monitoring_data/mendels_2024-05-08_15_57_03.mp4"
# monitor = BeeMonitor.from_config("/Users/edwardamoah/Documents/GitHub/BeeMonitor/default_config.yaml")
# results = monitor.analyze_video(filename)

# #file = filename.split("/")[-1].split(".mp4")[0]
# #results.to_csv(monitor.config.output.base_folder)              # ✅ WORKS!
# #results.save_video(monitor.config.output.base_folder)         # ✅ WORKS!
# stats = results.get_statistics()

# %%
# Complete end-to-end analysis!
monitor = BeeMonitor.from_config("/Users/edwardamoah/Documents/GitHub/BeeMonitor/default_config.yaml")

# %%
import os
import pandas as pd

# %%
import json

input_folder = "/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel"
folders = os.listdir(input_folder)
files = []
for folder in folders:
    folder_path = os.path.join(input_folder, folder)
    for file in os.listdir(folder_path):
        if file.endswith(".mp4"):
            files.append(os.path.join(folder_path, file))

# %%
for file in files:
    try:
        print(f"Processing video: {file}")
        nest = monitor.get_nest_detection(file)
        #nest.to_csv(output_folder
    except Exception as e:
        print(f"Error processing video {file}: {e}")
    

# output_folder = monitor.config.output.base_folder
# for file in os.listdir(input_folder):
#     if file.endswith(".mp4"):
#         try:
#             video_path = os.path.join(input_folder, file)
#             print(f"Processing video: {video_path}")
#             nest = monitor.get_nest_detection(video_path)
#             #nest.to_csv(output_folder+f"/{file.replace('.mp4', '_nest_detection.csv')}")

#             # nests = monitor.process_nest_detection(file, nest)
#             # # nests is a dictionary with nest IDs as keys and DataFrames as values, so save as json
#             # out_path = os.path.join(output_folder, file.replace('.mp4', '_nests.json'))
#             # #nests_serializable = {str(k): v.to_dict(orient='records') for k, v in nests.items()}
#             # with open(out_path, "w") as f:
#             #     json.dump(nests, f, indent=2)
#             # print(f"Saved nests JSON to: {out_path}")
#         except Exception as e:
#             print(f"Error processing video {video_path}: {e}")
# Out:
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_08_55_36.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_09_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_10_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_11_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_12_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_40_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_13_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_14_50_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_15_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_16_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_10_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_40_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_17_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_18_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_19_00_01.mp4
# Error processing video /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_19_00_01.mp4: Cannot open video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_19_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_08_55_36.mp4
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xa36805900] moov atom not found
# OpenCV: Couldn't read video stream from file "/Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-11/2024-05-11_19_00_01.mp4"
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_09_50_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_20_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_10_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_11_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_10_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_30_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_12_50_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_00_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_30_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_40_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_13_50_01.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_14_00_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_14_10_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_14_20_00.mp4
# Processing video: /Volumes/TOSHIBA_EXT/2024_Data/Osmia_Data/Mendels/beeHotel/2024-05-12/2024-05-12_14_30_01.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 try:
#       3     print(f"Processing video: {file}")
# ----> 4     nest = monitor.get_nest_detection(file)
#       5     #nest.to_csv(output_folder
#       6 except Exception as e:
#
# File ~/Documents/GitHub/BeeMonitor/src/beemonitor/core/video_analyzer.py:429, in BeeMonitor.get_nest_detection(self, video_path)
#     422 detector = ImprovedNestDetector(
#     423     model=self.nest_model,
#     424     config=self.config,
#     425     grid_config=grid_config
#     426 )
#     428 # Detect and assign IDs
# --> 429 nest_with_ids = detector.detect_and_assign_ids(
#     430     video_path=video_path,
#     431     res_height=self.res_height,
#     432     res_width=self.res_width,
#     433     max_frames=1000
#     434 )
#     436 # Save reference frame
#     437 #reference_folder = Path(self.config.output.base_folder) / "nest_references"
#     438 #reference_folder.mkdir(parents=True, exist_ok=True)
#     439 vd = video_path.split("/")[-1].split(".mp4")[0]
#
# File ~/Documents/GitHub/BeeMonitor/src/beemonitor/detection/improved_nest_detector.py:80, in ImprovedNestDetector.detect_and_assign_ids(self, video_path, res_height, res_width, max_frames)
#      77 logger.info("=" * 80)
#      79 # Step 1: Collect detections from multiple frames
# ---> 80 all_detections = self._collect_detections(
#      81     video_path, res_height, res_width, max_frames
#      82 )
#      83 logger.info(f"Collected {len(all_detections)} raw detections")
#      85 # Step 2: Merge overlapping detections
#
# File ~/Documents/GitHub/BeeMonitor/src/beemonitor/detection/improved_nest_detector.py:243, in ImprovedNestDetector._collect_detections(self, video_path, res_height, res_width, max_frames)
#     240 frame = cv2.resize(frame, (res_width, res_height))
#     242 # Run detection
# --> 243 results = self.model.predict(
#     244     frame,
#     245     conf=confidence_threshold,
#     246     verbose=False
#     247 )
#     249 boxes = results[0].boxes.xyxy.tolist()
#     250 labels = results[0].boxes.cls.tolist()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:557, in Model.predict(self, source, stream, predictor, **kwargs)
#     555 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556     self.predictor.set_prompts(prompts)
# --> 557 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:230, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     228     return self.stream_inference(source, model, *args, **kwargs)
#     229 else:
# --> 230     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:337, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     335 # Inference
#     336 with profilers[1]:
# --> 337     preds = self.inference(im, *args, **kwargs)
#     338     if self.args.embed:
#     339         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:185, in BasePredictor.inference(self, im, *args, **kwargs)
#     179 """Run inference on a given image using the specified model and arguments."""
#     180 visualize = (
#     181     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     182     if self.args.visualize and (not self.source_type.tensor)
#     183     else False
#     184 )
# --> 185 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:663, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     661 # PyTorch
#     662 if self.pt or self.nn_module:
# --> 663     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     665 # TorchScript
#     666 elif self.jit:
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:495, in Bottleneck.forward(self, x)
#     493 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     494     """Apply bottleneck with optional shortcut connection."""
# --> 495     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:93, in Conv.forward_fuse(self, x)
#      83 def forward_fuse(self, x):
#      84     """
#      85     Apply convolution and activation without batch normalization.
#      86
#    (...)     91         (torch.Tensor): Output tensor.
#      92     """
# ---> 93     return self.act(self.conv(x))
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Documents/GitHub/BeeMonitor/venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
